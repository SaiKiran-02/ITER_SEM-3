# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_csv('Employee.csv')
df.sample(5)
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 407   Bachelors         2015  Bangalore            3   28    Male          No
# 3667  Bachelors         2014  Bangalore            3   35    Male          No
# 4628  Bachelors         2013  Bangalore            3   39  Female          No
# 4178  Bachelors         2017  Bangalore            3   40    Male          No
# 1613  Bachelors         2014  Bangalore            3   25    Male          No
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 407                           2           0
# 3667                          0           1
# 4628                          5           0
# 4178                          0           0
# 1613                          3           0

# %%
df.shape
# Out:
# (4653, 9)

# %%
df.isnull().sum()
# Out:
# Education                    0
# JoiningYear                  0
# City                         0
# PaymentTier                  0
# Age                          0
# Gender                       0
# EverBenched                  0
# ExperienceInCurrentDomain    0
# LeaveOrNot                   0
# dtype: int64

# %%
df['ExperienceInCurrentDomain'].unique()
# Out:
# array([0, 3, 2, 5, 1, 4, 7, 6], dtype=int64)

# %%
plt.title('Box plot for Age ')

sns.boxplot(df['Age'],orient='h')
# Out:
# <Axes: title={'center': 'Box plot for Age '}, xlabel='Age'>

# %%
df.describe()
# Out:
#        JoiningYear  PaymentTier          Age  ExperienceInCurrentDomain  \
# count  4653.000000  4653.000000  4653.000000                4653.000000
# mean   2015.062970     2.698259    29.393295                   2.905652
# std       1.863377     0.561435     4.826087                   1.558240
# min    2012.000000     1.000000    22.000000                   0.000000
# 25%    2013.000000     3.000000    26.000000                   2.000000
# 50%    2015.000000     3.000000    28.000000                   3.000000
# 75%    2017.000000     3.000000    32.000000                   4.000000
# max    2018.000000     3.000000    41.000000                   7.000000
#
#         LeaveOrNot
# count  4653.000000
# mean      0.343864
# std       0.475047
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
plt.figure(figsize=(16,8))
plt.title('Bar Graphs')

plt.subplot(2,2,1)
sns.histplot(df['Education'],legend=True)

plt.subplot(2,2,2)
sns.histplot(df['JoiningYear'])

plt.subplot(2,2,3)
sns.histplot(df['City'])

plt.subplot(2,2,4)
sns.histplot(df['Gender'])

plt.show()

# %%
sns.pairplot(df)
plt.show()
